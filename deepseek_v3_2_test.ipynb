# %% [markdown]
# <a href="https://colab.research.google.com/github/lukaszlewickii/ai-engineering-playground/blob/main/deepseek_v3_2_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers==4.57.3 accelerate torch -q

# %%
# !pip install git+https://github.com/huggingface/transformers.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.2/516.2 kB 16.3 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 5.1.2 requires transformers<5.0.0,>=4.41.0, but you have transformers 5.0.0.dev0 which is incompatible.

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained("deepseek-ai/DeepSeek-V3.2")
model = AutoModelForCausalLM.from_pretrained(
    "deepseek-ai/DeepSeek-V3.2",
    torch_dtype="auto"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1359             raise ValueError(
# -> 1360                 "The config you are passing has a `model_type` attribute that is not consistent with the model type "
#    1361                 f"you passed (config has {config.model_type} and you passed {model_type}. Fix one of those so they "
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py in __getitem__(self, key)
#    1047
# -> 1048     def __iter__(self) -> Iterator[str]:
#    1049         return iter(list(self._mapping.keys()) + list(self._extra_content.keys()))
#
# KeyError: 'deepseek_v32'
#
# During handling of the above exception, another exception occurred:
#
# ...
